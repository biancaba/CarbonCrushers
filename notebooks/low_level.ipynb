# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt

sns.set_palette("husl", 8)
None

# %%
df = pd.read_csv("Food_Production.csv")

# %%
df
# Out:
#            Food product  Land use change  Animal Feed  Farm  Processing  \
# 0   Wheat & Rye (Bread)              0.1          0.0   0.8         0.2
# 1          Maize (Meal)              0.3          0.0   0.5         0.1
# 2         Barley (Beer)              0.0          0.0   0.2         0.1
# 3               Oatmeal              0.0          0.0   1.4         0.0
# 4                  Rice              0.0          0.0   3.6         0.1
# 5              Potatoes              0.0          0.0   0.2         0.0
# 6               Cassava              0.6          0.0   0.2         0.0
# 7            Cane Sugar              1.2          0.0   0.5         0.0
# 8            Beet Sugar              0.0          0.0   0.5         0.2
# 9          Other Pulses              0.0          0.0   1.1         0.0
# 10                 Peas              0.0          0.0   0.7         0.0
# 11                 Nuts             -2.1          0.0   2.1         0.0
# ...

# %%
filt_df = df[["Food product", "Animal Feed", "Farm", "Processing", "Transport", "Packging"]]
filt_df = filt_df.rename(columns={"Packging": "Packaging"})

# %%
filt_df
# Out:
#            Food product  Animal Feed  Farm  Processing  Transport  Packaging
# 0   Wheat & Rye (Bread)          0.0   0.8         0.2        0.1        0.1
# 1          Maize (Meal)          0.0   0.5         0.1        0.1        0.1
# 2         Barley (Beer)          0.0   0.2         0.1        0.0        0.5
# 3               Oatmeal          0.0   1.4         0.0        0.1        0.1
# 4                  Rice          0.0   3.6         0.1        0.1        0.1
# 5              Potatoes          0.0   0.2         0.0        0.1        0.0
# 6               Cassava          0.0   0.2         0.0        0.1        0.0
# 7            Cane Sugar          0.0   0.5         0.0        0.8        0.1
# 8            Beet Sugar          0.0   0.5         0.2        0.6        0.1
# 9          Other Pulses          0.0   1.1         0.0        0.1        0.4
# 10                 Peas          0.0   0.7         0.0        0.1        0.0
# ...

# %%
final_df = filt_df

final_df["Total"] = final_df[["Animal Feed", "Farm", "Processing", "Transport", "Packaging"]].sum(axis=1)

# %%
final_df
# Out:
#            Food product  Animal Feed  Farm  Processing  Transport  Packaging  \
# 0   Wheat & Rye (Bread)          0.0   0.8         0.2        0.1        0.1
# 1          Maize (Meal)          0.0   0.5         0.1        0.1        0.1
# 2         Barley (Beer)          0.0   0.2         0.1        0.0        0.5
# 3               Oatmeal          0.0   1.4         0.0        0.1        0.1
# 4                  Rice          0.0   3.6         0.1        0.1        0.1
# 5              Potatoes          0.0   0.2         0.0        0.1        0.0
# 6               Cassava          0.0   0.2         0.0        0.1        0.0
# 7            Cane Sugar          0.0   0.5         0.0        0.8        0.1
# 8            Beet Sugar          0.0   0.5         0.2        0.6        0.1
# 9          Other Pulses          0.0   1.1         0.0        0.1        0.4
# 10                 Peas          0.0   0.7         0.0        0.1        0.0
# ...

# %%
json_string = final_df.to_json(orient="records")

# %%
json_string
# Out:
# '[{"Food product":"Wheat & Rye (Bread)","Animal Feed":0.0,"Farm":0.8,"Processing":0.2,"Transport":0.1,"Packaging":0.1,"Total":1.2},{"Food product":"Maize (Meal)","Animal Feed":0.0,"Farm":0.5,"Processing":0.1,"Transport":0.1,"Packaging":0.1,"Total":0.8},{"Food product":"Barley (Beer)","Animal Feed":0.0,"Farm":0.2,"Processing":0.1,"Transport":0.0,"Packaging":0.5,"Total":0.8},{"Food product":"Oatmeal","Animal Feed":0.0,"Farm":1.4,"Processing":0.0,"Transport":0.1,"Packaging":0.1,"Total":1.6},{"Food product":"Rice","Animal Feed":0.0,"Farm":3.6,"Processing":0.1,"Transport":0.1,"Packaging":0.1,"Total":3.9},{"Food product":"Potatoes","Animal Feed":0.0,"Farm":0.2,"Processing":0.0,"Transport":0.1,"Packaging":0.0,"Total":0.3},{"Food product":"Cassava","Animal Feed":0.0,"Farm":0.2,"Processing":0.0,"Transport":0.1,"Packaging":0.0,"Total":0.3},{"Food product":"Cane Sugar","Animal Feed":0.0,"Farm":0.5,"Processing":0.0,"Transport":0.8,"Packaging":0.1,"Total":1.4},{"Food product":"Beet Sugar","Animal
# ...

# %%
with open("low_level_json.txt", "w") as file:
    file.write(json_string)

# %% [markdown]
# ### Adding score columns

# %%
af_df = filt_df[filt_df["Animal Feed"] != 0]

# %%
thresh_1 = af_df["Animal Feed"].quantile(0.2)
thresh_2 = af_df["Animal Feed"].quantile(0.4)
thresh_3 = af_df["Animal Feed"].quantile(0.6)
thresh_4 = af_df["Animal Feed"].quantile(0.8)

thresh_1, thresh_2, thresh_3, thresh_4
# Out:
# (1.6, 2.08, 2.34, 2.5)

# %%
filt_df["Animal_Feed_Score"] = pd.Series([0 for x in range(len(filt_df))])
for i in range(len(filt_df)):
    val = filt_df["Animal Feed"].iloc[i]
    if val == 0:
        pass
    elif val <= thresh_1:
        filt_df["Animal_Feed_Score"].iloc[i] = 1
    elif val <= thresh_2:
        filt_df["Animal_Feed_Score"].iloc[i] = 2
    elif val <= thresh_3:
        filt_df["Animal_Feed_Score"].iloc[i] = 3
    elif val <= thresh_4:
        filt_df["Animal_Feed_Score"].iloc[i] = 4
    else:
        filt_df["Animal_Feed_Score"].iloc[i] = 5
# Out:
# c:\users\sarah\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py:1636: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
thresh_1 = filt_df["Farm"].quantile(0.2)
thresh_2 = filt_df["Farm"].quantile(0.4)
thresh_3 = filt_df["Farm"].quantile(0.6)
thresh_4 = filt_df["Farm"].quantile(0.8)

thresh_1, thresh_2, thresh_3, thresh_4
# Out:
# (0.3, 0.68, 1.42, 3.5999999999999996)

# %%
filt_df["Farm_Score"] = pd.Series([0 for x in range(len(filt_df))])
for i in range(len(filt_df)):
    val = filt_df["Farm"].iloc[i]
    if val <= thresh_1:
        filt_df["Farm_Score"].iloc[i] = 1
    elif val <= thresh_2:
        filt_df["Farm_Score"].iloc[i] = 2
    elif val <= thresh_3:
        filt_df["Farm_Score"].iloc[i] = 3
    elif val <= thresh_4:
        filt_df["Farm_Score"].iloc[i] = 4
    else:
        filt_df["Farm_Score"].iloc[i] = 5

# %%
thresh_1 = filt_df["Processing"].quantile(0.2)
thresh_2 = filt_df["Processing"].quantile(0.4)
thresh_3 = filt_df["Processing"].quantile(0.6)
thresh_4 = filt_df["Processing"].quantile(0.8)

thresh_1, thresh_2, thresh_3, thresh_4
# Out:
# (0.0, 0.0, 0.2, 0.4)

# %%
filt_df["Processing_Score"] = pd.Series([0 for x in range(len(filt_df))])
for i in range(len(filt_df)):
    val = filt_df["Processing"].iloc[i]
    if val <= thresh_1:
        filt_df["Processing_Score"].iloc[i] = 1
    elif val <= thresh_2:
        filt_df["Processing_Score"].iloc[i] = 2
    elif val <= thresh_3:
        filt_df["Processing_Score"].iloc[i] = 3
    elif val <= thresh_4:
        filt_df["Processing_Score"].iloc[i] = 4
    else:
        filt_df["Processing_Score"].iloc[i] = 5

# %%
thresh_1 = filt_df["Transport"].quantile(0.2)
thresh_2 = filt_df["Transport"].quantile(0.4)
thresh_3 = filt_df["Transport"].quantile(0.6)
thresh_4 = filt_df["Transport"].quantile(0.8)

thresh_1, thresh_2, thresh_3, thresh_4
# Out:
# (0.1, 0.1, 0.2, 0.3)

# %%
filt_df["Transport_Score"] = pd.Series([0 for x in range(len(filt_df))])
for i in range(len(filt_df)):
    val = filt_df["Transport"].iloc[i]
    if val <= thresh_1:
        filt_df["Transport_Score"].iloc[i] = 1
    elif val <= thresh_2:
        filt_df["Transport_Score"].iloc[i] = 2
    elif val <= thresh_3:
        filt_df["Transport_Score"].iloc[i] = 3
    elif val <= thresh_4:
        filt_df["Transport_Score"].iloc[i] = 4
    else:
        filt_df["Transport_Score"].iloc[i] = 5

# %%
thresh_1 = filt_df["Packaging"].quantile(0.2)
thresh_2 = filt_df["Packaging"].quantile(0.4)
thresh_3 = filt_df["Packaging"].quantile(0.6)
thresh_4 = filt_df["Packaging"].quantile(0.8)

thresh_1, thresh_2, thresh_3, thresh_4
# Out:
# (0.0, 0.1, 0.2, 0.4)

# %%
filt_df["Packaging_Score"] = pd.Series([0 for x in range(len(filt_df))])
for i in range(len(filt_df)):
    val = filt_df["Packaging"].iloc[i]
    if val <= thresh_1:
        filt_df["Packaging_Score"].iloc[i] = 1
    elif val <= thresh_2:
        filt_df["Packaging_Score"].iloc[i] = 2
    elif val <= thresh_3:
        filt_df["Packaging_Score"].iloc[i] = 3
    elif val <= thresh_4:
        filt_df["Packaging_Score"].iloc[i] = 4
    else:
        filt_df["Packaging_Score"].iloc[i] = 5

# %%
filt_df
# Out:
#            Food product  Animal Feed  Farm  Processing  Transport  Packaging  \
# 0   Wheat & Rye (Bread)          0.0   0.8         0.2        0.1        0.1
# 1          Maize (Meal)          0.0   0.5         0.1        0.1        0.1
# 2         Barley (Beer)          0.0   0.2         0.1        0.0        0.5
# 3               Oatmeal          0.0   1.4         0.0        0.1        0.1
# 4                  Rice          0.0   3.6         0.1        0.1        0.1
# 5              Potatoes          0.0   0.2         0.0        0.1        0.0
# 6               Cassava          0.0   0.2         0.0        0.1        0.0
# 7            Cane Sugar          0.0   0.5         0.0        0.8        0.1
# 8            Beet Sugar          0.0   0.5         0.2        0.6        0.1
# 9          Other Pulses          0.0   1.1         0.0        0.1        0.4
# 10                 Peas          0.0   0.7         0.0        0.1        0.0
# ...

# %%
sns.countplot(filt_df["Animal_Feed_Score"])
None
# Out:
# c:\users\sarah\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(filt_df["Farm_Score"])
None
# Out:
# c:\users\sarah\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(filt_df["Processing_Score"])
None
# Out:
# c:\users\sarah\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(filt_df["Transport_Score"])
# Out:
# c:\users\sarah\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Transport_Score', ylabel='count'>

# %%
sns.countplot(filt_df["Packaging_Score"])
# Out:
# c:\users\sarah\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Packaging_Score', ylabel='count'>

# %%
af_df["Animal Feed"].min(), af_df["Animal Feed"].max()
# Out:
# (0.2, 2.9)

# %%
filt_df["Farm"].min(), filt_df["Farm"].max()
# Out:
# (0.1, 39.4)

# %%
filt_df["Processing"].min(), filt_df["Processing"].max()
# Out:
# (0.0, 1.3)

# %%
filt_df["Transport"].min(), filt_df["Transport"].max()
# Out:
# (0.0, 0.8)

# %%
filt_df["Packaging"].min(), filt_df["Packaging"].max()
# Out:
# (0.0, 1.6)

# %%
filt_df.to_csv("low_level_data.csv")

# %%
json_string = filt_df.to_json(orient="records")

# %%
with open("low_level_json.txt", "w") as file:
    file.write(json_string)
